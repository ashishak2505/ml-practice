# %%
import pandas as pd
import seaborn as sns
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
beer_df = pd.read_csv(r'C:\Users\Ashish\Desktop\machine learning\beer.csv')
beer_df
# Out:
#                     name  calories  sodium  alcohol  cost
# 0              Budweiser       144      15      4.7  0.43
# 1                Schlitz       151      19      4.9  0.43
# 2              Lowenbrau       157      15      0.9  0.48
# 3            Kronenbourg       170       7      5.2  0.73
# 4               Heineken       152      11      5.0  0.77
# 5          Old_Milwaukee       145      23      4.6  0.28
# 6             Augsberger       175      24      5.5  0.40
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42
# 8            Miller_Lite        99      10      4.3  0.43
# 9        Budweiser_Light       113       8      3.7  0.40
# 10                 Coors       140      18      4.6  0.44
# 11           Coors_Light       102      15      4.1  0.46
# 12        Michelob_Light       135      11      4.2  0.50
# 13                 Becks       150      19      4.7  0.76
# 14                 Kirin       149       6      5.0  0.79
# 15     Pabst_Extra_Light        68      15      2.3  0.38
# 16                 Hamms       139      19      4.4  0.43
# 17   Heilemans_Old_Style       144      24      4.9  0.43
# 18   Olympia_Goled_Light        72       6      2.9  0.46
# 19         Schlitz_Light        97       7      4.2  0.47

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_beer_df = scaler.fit_transform(beer_df[['calories', 'sodium', 'alcohol','cost']])

# %%
cmap = sns.cubehelix_palette(as_cmap = True, rot =-0.3, light = 1)
sns.clustermap(scaled_beer_df, cmap = cmap, linewidths = 0.2, figsize = (8,8));

# %%
beer_df.iloc[[10,16]]
# Out:
#      name  calories  sodium  alcohol  cost
# 10  Coors       140      18      4.6  0.44
# 16  Hamms       139      19      4.4  0.43

# %%
beer_df.iloc[[2,18]]
# Out:
#                    name  calories  sodium  alcohol  cost
# 2             Lowenbrau       157      15      0.9  0.48
# 18  Olympia_Goled_Light        72       6      2.9  0.46

# %%
beer_df.iloc[[17,11]]
# Out:
#                    name  calories  sodium  alcohol  cost
# 17  Heilemans_Old_Style       144      24      4.9  0.43
# 11          Coors_Light       102      15      4.1  0.46

# %%
cluster_range= range(1,10)
cluster_errors = []
for num_clusters in cluster_range:
    clusters = KMeans(num_clusters)
    clusters.fit(scaled_beer_df)
    cluster_errors.append(clusters.inertia_)
plt.figure(figsize = (6,4))
plt.plot(cluster_range, cluster_errors, marker = "o")
plt.show()
# Out:
# C:\Users\Ashish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ashish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ashish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ashish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ashish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ashish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ashish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ashish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\Ashish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
scaled_beer_df = scaler.fit_transform(beer_df[['calories', 'sodium', 'alcohol','cost']])

# %%
k= 3
clusters = KMeans(k, random_state=42)
clusters.fit(scaled_beer_df)
beer_df["clusterid"]= clusters.labels_
# Out:
# C:\Users\Ashish\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
beer_df[beer_df.clusterid==0]
# Out:
#                     name  calories  sodium  alcohol  cost  clusterid
# 0              Budweiser       144      15      4.7  0.43          0
# 1                Schlitz       151      19      4.9  0.43          0
# 5          Old_Milwaukee       145      23      4.6  0.28          0
# 6             Augsberger       175      24      5.5  0.40          0
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42          0
# 10                 Coors       140      18      4.6  0.44          0
# 13                 Becks       150      19      4.7  0.76          0
# 16                 Hamms       139      19      4.4  0.43          0
# 17   Heilemans_Old_Style       144      24      4.9  0.43          0

# %%
beer_df[beer_df.clusterid==1]
# Out:
#                    name  calories  sodium  alcohol  cost  clusterid
# 3           Kronenbourg       170       7      5.2  0.73          1
# 4              Heineken       152      11      5.0  0.77          1
# 8           Miller_Lite        99      10      4.3  0.43          1
# 9       Budweiser_Light       113       8      3.7  0.40          1
# 11          Coors_Light       102      15      4.1  0.46          1
# 12       Michelob_Light       135      11      4.2  0.50          1
# 14                Kirin       149       6      5.0  0.79          1
# 15    Pabst_Extra_Light        68      15      2.3  0.38          1
# 18  Olympia_Goled_Light        72       6      2.9  0.46          1
# 19        Schlitz_Light        97       7      4.2  0.47          1

# %%
beer_df[beer_df.clusterid==2]
# Out:
#         name  calories  sodium  alcohol  cost  clusterid
# 2  Lowenbrau       157      15      0.9  0.48          2

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
h_clusters = AgglomerativeClustering(3)
h_clusters.fit(scaled_beer_df)
beer_df["h_clusterid"] = h_clusters.labels_

# %%
beer_df[beer_df.h_clusterid ==0]
# Out:
#                    name  calories  sodium  alcohol  cost  clusterid  \
# 2             Lowenbrau       157      15      0.9  0.48          2
# 8           Miller_Lite        99      10      4.3  0.43          1
# 9       Budweiser_Light       113       8      3.7  0.40          1
# 11          Coors_Light       102      15      4.1  0.46          1
# 12       Michelob_Light       135      11      4.2  0.50          1
# 15    Pabst_Extra_Light        68      15      2.3  0.38          1
# 18  Olympia_Goled_Light        72       6      2.9  0.46          1
# 19        Schlitz_Light        97       7      4.2  0.47          1
#
#     h_clusterid
# 2             0
# 8             0
# 9             0
# 11            0
# 12            0
# 15            0
# 18            0
# 19            0

# %%
beer_df[beer_df.h_clusterid ==1]
# Out:
#                     name  calories  sodium  alcohol  cost  clusterid  \
# 0              Budweiser       144      15      4.7  0.43          0
# 1                Schlitz       151      19      4.9  0.43          0
# 5          Old_Milwaukee       145      23      4.6  0.28          0
# 6             Augsberger       175      24      5.5  0.40          0
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42          0
# 10                 Coors       140      18      4.6  0.44          0
# 16                 Hamms       139      19      4.4  0.43          0
# 17   Heilemans_Old_Style       144      24      4.9  0.43          0
#
#     h_clusterid
# 0             1
# 1             1
# 5             1
# 6             1
# 7             1
# 10            1
# 16            1
# 17            1

# %%
beer_df[beer_df.h_clusterid ==2]
# Out:
#            name  calories  sodium  alcohol  cost  clusterid  h_clusterid
# 3   Kronenbourg       170       7      5.2  0.73          1            2
# 4      Heineken       152      11      5.0  0.77          1            2
# 13        Becks       150      19      4.7  0.76          0            2
# 14        Kirin       149       6      5.0  0.79          1            2
